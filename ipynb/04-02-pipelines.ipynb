# %%
from lib import create_mongo_client_to_database_collection

collection_reference = create_mongo_client_to_database_collection('twitter', 'tweets')

# %%
collection_reference.count_documents({})
# Out:
# 16417

# %%
cursor_sampl = collection_reference.aggregate([{'$sample': {'size': 50}}])

# %%
list(cursor_sampl)
# Out:
# [{'_id': ObjectId('5b59335935c77d003438b06a'),
#   'created_at': 'Thu Jul 26 02:33:42 +0000 2018',
#   'id': 1022308950362845184,
#   'id_str': '1022308950362845184',
#   'text': 'Appreciate you Billy. https://t.co/D8v6zmmbQd',
#   'display_text_range': [0, 21],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 328866492,
#    'id_str': '328866492',
#    'name': 'Aaron Larsuel',
#    'screen_name': 'AaronLarsuel',
#    'location': 'Where I be.',
#    'url': 'https://itunes.apple.com/us/podcast/americas-lakers-podcast/id1297661311?mt=2',
#    'description': 'Host & Producer of America’s Lakers Podcast, official podcast of @Lakers, on @PodcastOne. Big Spoon. IG: @aaronlarsuel  Hit that SUBSCRIBE!!👇🏾',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 851,
#    'friends_count': 279,
#    'listed_count': 18,
#    'favourites_count': 2151,
#    'statuses_count': 1687,
#    'created_at': 'Mon Jul 04 05:04:46 +0000 2011',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3096661963/ceee95cf5eb3e540db8c6d13cbe50e2a_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3096661963/ceee95cf5eb3e540db8c6d13cbe50e2a_normal.jpeg',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'quoted_status_id': 1022274200743108608,
#   'quoted_status_id_str': '1022274200743108608',
#   'quoted_status': {'created_at': 'Thu Jul 26 00:15:37 +0000 2018',
#    'id': 1022274200743108608,
#    'id_str': '1022274200743108608',
#    'text': ". @AaronLarsuel Aaron Larsuel is THE MOST informative voice in Basketball 🏀 He's great for @Lakers &amp; GREAT for BASK… https://t.co/Z81183mtgo",
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 952507806,
#     'id_str': '952507806',
#     'name': '🐔Billy Hayes🐓',
#     'screen_name': 'Billyhayes16',
#     'location': None,
#     'url': None,
#     'description': 'military veteran of this great Nation 🇺🇸born & raised Marine park, Brooklyn! J E T S JETS JETS JETS 💚💚💚💚Go Lakers 💜💛💜💛💜💛Go Dodgers 💙💙💙',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 355,
#     'friends_count': 318,
#     'listed_count': 0,
#     'favourites_count': 16783,
#     'statuses_count': 12095,
#     'created_at': 'Fri Nov 16 22:25:44 +0000 2012',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1022018031101337601/Qi4erTfE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1022018031101337601/Qi4erTfE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/952507806/1532503065',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '27485069891a7938',
#     'url': 'https://api.twitter.com/1.1/geo/id/27485069891a7938.json',
#     'place_type': 'admin',
#     'name': 'New York',
#     'full_name': 'New York, NY',
#     'country_code': 'US',
#     'country': 'United States',
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-74.255641, 40.495865],
#        [-74.255641, 40.91533],
#        [-73.699793, 40.91533],
#        [-73.699793, 40.495865]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': ". @AaronLarsuel Aaron Larsuel is THE MOST informative voice in Basketball 🏀 He's great for @Lakers &amp; GREAT for BASKETBALL! I can listen to him all day long! His #ALP Is great. Radio &amp; TV are on deck 💜💛  @CBSSportsRadio @sportsreiter @PodcastOne  @noble_darrin #purpleandgold",
#     'display_text_range': [0, 282],
#     'entities': {'hashtags': [{'text': 'ALP', 'indices': [165, 169]},
#       {'text': 'purpleandgold', 'indices': [268, 282]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'AaronLarsuel',
#        'name': 'Aaron Larsuel',
#        'id': 328866492,
#        'id_str': '328866492',
#        'indices': [2, 15]},
#       {'screen_name': 'Lakers',
#        'name': 'Los Angeles Lakers',
#        'id': 20346956,
#        'id_str': '20346956',
#        'indices': [91, 98]},
#       {'screen_name': 'CBSSportsRadio',
#        'name': 'CBS Sports Radio',
#        'id': 809385470,
#        'id_str': '809385470',
#        'indices': [211, 226]},
#       {'screen_name': 'sportsreiter',
#        'name': 'Bill Reiter',
#        'id': 128427810,
#        'id_str': '128427810',
#        'indices': [227, 240]},
#       {'screen_name': 'PodcastOne',
#        'name': 'PodcastOne',
#        'id': 1154563242,
#        'id_str': '1154563242',
#        'indices': [241, 252]},
#       {'screen_name': 'noble_darrin',
#        'name': 'D in Colorado',
#        'id': 2472035864,
#        'id_str': '2472035864',
#        'indices': [254, 267]}],
#      'symbols': []}},
#    'quote_count': 1,
#    'reply_count': 2,
#    'retweet_count': 1,
#    'favorite_count': 5,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/Z81183mtgo',
#       'expanded_url': 'https://twitter.com/i/web/status/1022274200743108608',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}],
#     'user_mentions': [{'screen_name': 'AaronLarsuel',
#       'name': 'Aaron Larsuel',
#       'id': 328866492,
#       'id_str': '328866492',
#       'indices': [2, 15]},
#      {'screen_name': 'Lakers',
#       'name': 'Los Angeles Lakers',
#       'id': 20346956,
#       'id_str': '20346956',
#       'indices': [91, 98]}],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/D8v6zmmbQd',
#    'expanded': 'https://twitter.com/billyhayes16/status/1022274200743108608',
#    'display': 'twitter.com/billyhayes16/s…'},
#   'is_quote_status': True,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/D8v6zmmbQd',
#      'expanded_url': 'https://twitter.com/billyhayes16/status/1022274200743108608',
#      'display_url': 'twitter.com/billyhayes16/s…',
#      'indices': [22, 45]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532572422005'},
#  {'_id': ObjectId('5b5933c835c77d003438b0cc'),
#   'created_at': 'Thu Jul 26 02:35:31 +0000 2018',
#   'id': 1022309411174273024,
#   'id_str': '1022309411174273024',
#   'text': '@Starbucks I asked the guy to come to the door and he said no and turned his back. Now I have to pay for parking. G… https://t.co/Lwde9UEbGZ',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 30973,
#   'in_reply_to_user_id_str': '30973',
#   'in_reply_to_screen_name': 'Starbucks',
#   'user': {'id': 45786887,
#    'id_str': '45786887',
#    'name': 'Tiwana Floyd',
#    'screen_name': 'TiwanaFloyd',
#    'location': 'Los Angeles',
#    'url': 'http://www.tiwanafloyd.com',
#    'description': 'Actor • Singer • Eyewear-er • Native NYr • Seer • Oprah Lover • Universal Principler • Perpetual Optimist',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 639,
#    'friends_count': 568,
#    'listed_count': 63,
#    'favourites_count': 55,
#    'statuses_count': 2879,
#    'created_at': 'Tue Jun 09 07:13:32 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'DD2E44',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/914720237085384704/lBk1zNI7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/914720237085384704/lBk1zNI7_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/45786887/1506921195',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '@Starbucks I asked the guy to come to the door and he said no and turned his back. Now I have to pay for parking. Geez, if you look at my Starbucks app history you’ll see I frequent this location often for the 7 years I’ve lived at this location.',
#    'display_text_range': [0, 246],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'Starbucks',
#       'name': 'Starbucks Coffee',
#       'id': 30973,
#       'id_str': '30973',
#       'indices': [0, 10]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/Lwde9UEbGZ',
#      'expanded_url': 'https://twitter.com/i/web/status/1022309411174273024',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}],
#    'user_mentions': [{'screen_name': 'Starbucks',
#      'name': 'Starbucks Coffee',
#      'id': 30973,
#      'id_str': '30973',
#      'indices': [0, 10]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532572531871'},
#  {'_id': ObjectId('5b5923de0cff4002d5673f84'),
#   'created_at': 'Sat Jul 21 20:58:43 +0000 2018',
#   'id': 1020775097898917888,
#   'id_str': '1020775097898917888',
#   'text': 'Can’t wait to go home and play video games already smh',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3096943027,
#    'id_str': '3096943027',
#    'name': 'mattygeee',
#    'screen_name': 'Mattygeee1',
#    'location': 'Los Angeles, CA',
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 286,
#    'friends_count': 399,
#    'listed_count': 4,
#    'favourites_count': 7501,
#    'statuses_count': 17775,
#    'created_at': 'Thu Mar 19 01:14:05 +0000 2015',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/976278641431650304/QDCKALf8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976278641431650304/QDCKALf8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3096943027/1522005281',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '59612bd882018c51',
#    'url': 'https://api.twitter.com/1.1/geo/id/59612bd882018c51.json',
#    'place_type': 'city',
#    'name': 'Santa Monica',
#    'full_name': 'Santa Monica, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.517358, 33.995177],
#       [-118.517358, 34.050199],
#       [-118.443482, 34.050199],
#       [-118.443482, 33.995177]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532206723080'},
#  {'_id': ObjectId('5b58c5383aed5a010fe921d8'),
#   'created_at': 'Wed Jul 25 18:40:49 +0000 2018',
#   'id': 1022189949511262209,
#   'id_str': '1022189949511262209',
#   'text': 'Pure vegan hyaluronic acid is our best-selling product! We’re obsessed with it, how about you?\n.\n.\n.\n.\n#saian… https://t.co/GdJ9kg0T7M',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 75552647,
#    'id_str': '75552647',
#    'name': 'SAIAN Skin Care',
#    'screen_name': 'Saian_Skincare',
#    'location': 'North Hollywood, CA',
#    'url': 'http://www.saian.net',
#    'description': 'Natural. Clinical. Luxurious. Pure. Never tested on animals, no parabens, hypoallergenic, recommended by estheticians, 100% active! Made in USA.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 5234,
#    'friends_count': 2872,
#    'listed_count': 18,
#    'favourites_count': 181,
#    'statuses_count': 2735,
#    'created_at': 'Sat Sep 19 13:52:02 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '666466',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/821512067844669440/xsu3OsPt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/821512067844669440/xsu3OsPt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75552647/1482783330',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [34.20266159, -118.39198891]},
#   'coordinates': {'type': 'Point',
#    'coordinates': [-118.39198891, 34.20266159]},
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'Pure vegan hyaluronic acid is our best-selling product! We’re obsessed with it, how about you?\n.\n.\n.\n.\n#saian #naturalskincare #beauty #mua #esty #esthetician #estheticians… https://t.co/V42RetDWjG',
#    'display_text_range': [0, 197],
#    'entities': {'hashtags': [{'text': 'saian', 'indices': [103, 109]},
#      {'text': 'naturalskincare', 'indices': [110, 126]},
#      {'text': 'beauty', 'indices': [127, 134]},
#      {'text': 'mua', 'indices': [135, 139]},
#      {'text': 'esty', 'indices': [140, 145]},
#      {'text': 'esthetician', 'indices': [146, 158]},
#      {'text': 'estheticians', 'indices': [159, 172]}],
#     'urls': [{'url': 'https://t.co/V42RetDWjG',
#       'expanded_url': 'https://www.instagram.com/p/BlqkBNQH3_U/?utm_source=ig_twitter_share&igshid=w62ij6svcz8x',
#       'display_url': 'instagram.com/p/BlqkBNQH3_U/…',
#       'indices': [174, 197]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'saian', 'indices': [103, 109]}],
#    'urls': [{'url': 'https://t.co/GdJ9kg0T7M',
#      'expanded_url': 'https://twitter.com/i/web/status/1022189949511262209',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [111, 134]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532544049991'},
#  {'_id': ObjectId('5b58bac53aed5a010fe919b2'),
#   'created_at': 'Wed Jul 25 17:56:29 +0000 2018',
#   'id': 1022178791895060480,
#   'id_str': '1022178791895060480',
#   'text': "I'm at Delta Sky Club Terminal 3 in Los Angeles, CA https://t.co/2q8qNwo00k",
#   'source': '<a href="http://foursquare.com" rel="nofollow">Foursquare</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 20604749,
#    'id_str': '20604749',
#    'name': 'Oliver McGill',
#    'screen_name': 'oliverdmcgill',
#    'location': 'New York, NY',
#    'url': None,
#    'description': 'English man in New York...',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 266,
#    'friends_count': 553,
#    'listed_count': 10,
#    'favourites_count': 692,
#    'statuses_count': 7505,
#    'created_at': 'Wed Feb 11 17:28:55 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/722396323480215553/zelVBD3V_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/722396323480215553/zelVBD3V_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20604749/1461067679',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [33.94662401, -118.40732373]},
#   'coordinates': {'type': 'Point',
#    'coordinates': [-118.40732373, 33.94662401]},
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/2q8qNwo00k',
#      'expanded_url': 'https://www.swarmapp.com/c/0aVi1DTbYS4',
#      'display_url': 'swarmapp.com/c/0aVi1DTbYS4',
#      'indices': [52, 75]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532541389808'},
#  {'_id': ObjectId('5b58bb8e3aed5a010fe91a2b'),
#   'created_at': 'Wed Jul 25 17:59:02 +0000 2018',
#   'id': 1022179432184705024,
#   'id_str': '1022179432184705024',
#   'text': '@MarshaWarfield I am not one of them.',
#   'display_text_range': [16, 37],
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021001698624589824,
#   'in_reply_to_status_id_str': '1021001698624589824',
#   'in_reply_to_user_id': 123712660,
#   'in_reply_to_user_id_str': '123712660',
#   'in_reply_to_screen_name': 'MarshaWarfield',
#   'user': {'id': 97818356,
#    'id_str': '97818356',
#    'name': 'Paula J K Goldberg',
#    'screen_name': 'Aamazon1',
#    'location': 'Valley Vilage, CA 91607',
#    'url': None,
#    'description': "An over-educated, Amazon. Live a little, love a little and laugh a lot. Blonde Bombshell that should be a Stepford wife, but I don't roll like that",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 237,
#    'friends_count': 255,
#    'listed_count': 5,
#    'favourites_count': 2205,
#    'statuses_count': 24396,
#    'created_at': 'Sat Dec 19 04:23:16 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '642D8B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000420729977/b074a7255f3777d619eae05c17ba92aa_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000420729977/b074a7255f3777d619eae05c17ba92aa_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/97818356/1361906640',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'MarshaWarfield',
#      'name': 'Marsha Warfield',
#      'id': 123712660,
#      'id_str': '123712660',
#      'indices': [0, 15]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532541542465'},
#  {'_id': ObjectId('5b56aa551a6d22025b8c02dd'),
#   'created_at': 'Tue Jul 24 03:12:25 +0000 2018',
#   'id': 1021593920700997632,
#   'id_str': '1021593920700997632',
#   'text': '@michaeluzowuru Congrats Michael! 🤴🏿 🇳🇬',
#   'display_text_range': [16, 39],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021581695894450176,
#   'in_reply_to_status_id_str': '1021581695894450176',
#   'in_reply_to_user_id': 1932982448,
#   'in_reply_to_user_id_str': '1932982448',
#   'in_reply_to_screen_name': 'michaeluzowuru',
#   'user': {'id': 160276691,
#    'id_str': '160276691',
#    'name': 'Timmy.',
#    'screen_name': 'TrueLifeOfTimmy',
#    'location': 'Los Angeles',
#    'url': None,
#    'description': 'A true legend in the making.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 3440,
#    'friends_count': 455,
#    'listed_count': 54,
#    'favourites_count': 63062,
#    'statuses_count': 77823,
#    'created_at': 'Sun Jun 27 18:30:03 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FFCC4D',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_link_color': 'FFCC4D',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1018995945923436544/rh3ndmNy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1018995945923436544/rh3ndmNy_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/160276691/1531432279',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'michaeluzowuru',
#      'name': 'michael uzowuru',
#      'id': 1932982448,
#      'id_str': '1932982448',
#      'indices': [0, 15]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532401945649'},
#  {'_id': ObjectId('5b56a472e7f6080052705142'),
#   'created_at': 'Tue Jul 24 02:00:04 +0000 2018',
#   'id': 1021575712296263681,
#   'id_str': '1021575712296263681',
#   'text': '@pahubb43 Peggy good for you! Know your story of with what happened to your husband being shot and how it affected… https://t.co/IZbjc8P14U',
#   'display_text_range': [10, 140],
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': True,
#   'in_reply_to_status_id': 1021562834239541249,
#   'in_reply_to_status_id_str': '1021562834239541249',
#   'in_reply_to_user_id': 801640934,
#   'in_reply_to_user_id_str': '801640934',
#   'in_reply_to_screen_name': 'pahubb43',
#   'user': {'id': 966871888424181761,
#    'id_str': '966871888424181761',
#    'name': 'Cynthia Jean Sheaffer',
#    'screen_name': 'sheaffer_jean',
#    'location': None,
#    'url': None,
#    'description': '#Happily Married.Trump Supporter.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1583,
#    'friends_count': 2919,
#    'listed_count': 7,
#    'favourites_count': 18259,
#    'statuses_count': 20232,
#    'created_at': 'Fri Feb 23 03:06:36 +0000 2018',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '@pahubb43 Peggy good for you! Know your story of with what happened to your husband being shot and how it affected  your family and you! You speak for truth and know my prayers and my admiration to you!',
#    'display_text_range': [10, 202],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'pahubb43',
#       'name': 'Peggy A Hubbard 🇺🇸',
#       'id': 801640934,
#       'id_str': '801640934',
#       'indices': [0, 9]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/IZbjc8P14U',
#      'expanded_url': 'https://twitter.com/i/web/status/1021575712296263681',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}],
#    'user_mentions': [{'screen_name': 'pahubb43',
#      'name': 'Peggy A Hubbard 🇺🇸',
#      'id': 801640934,
#      'id_str': '801640934',
#      'indices': [0, 9]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532397604427'},
#  {'_id': ObjectId('5b569d0a9874910127074276'),
#   'created_at': 'Tue Jul 24 02:16:14 +0000 2018',
#   'id': 1021579783027613698,
#   'id_str': '1021579783027613698',
#   'text': '@CarlosE_Lozada Todo es posible en la dimensión desconocida.',
#   'display_text_range': [16, 60],
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021573532193644546,
#   'in_reply_to_status_id_str': '1021573532193644546',
#   'in_reply_to_user_id': 117506621,
#   'in_reply_to_user_id_str': '117506621',
#   'in_reply_to_screen_name': 'CarlosE_Lozada',
#   'user': {'id': 170527793,
#    'id_str': '170527793',
#    'name': 'Iraima Vivas',
#    'screen_name': 'iraimavivast',
#    'location': 'En alguna cocina, California',
#    'url': None,
#    'description': 'Ama que se va el día.\n\nEugenio Montejo',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 3201,
#    'friends_count': 3658,
#    'listed_count': 53,
#    'favourites_count': 14217,
#    'statuses_count': 109085,
#    'created_at': 'Sun Jul 25 02:38:26 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'es',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1018726536852066305/X8bbIVjS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1018726536852066305/X8bbIVjS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170527793/1531280989',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'Estados Unidos',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'CarlosE_Lozada',
#      'name': 'Carlos Emigdio Lozada',
#      'id': 117506621,
#      'id_str': '117506621',
#      'indices': [0, 15]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'es',
#   'timestamp_ms': '1532398574965'},
#  {'_id': ObjectId('5b5937781a6d220be7f18c0d'),
#   'created_at': 'Thu Jul 26 02:51:45 +0000 2018',
#   'id': 1022313496581570561,
#   'id_str': '1022313496581570561',
#   'text': 'His Toupee for one https://t.co/3vtiTs84A3',
#   'display_text_range': [0, 18],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 509437828,
#    'id_str': '509437828',
#    'name': 'Jason Thompson',
#    'screen_name': 'JaySway52',
#    'location': None,
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1125,
#    'friends_count': 4999,
#    'listed_count': 23,
#    'favourites_count': 44787,
#    'statuses_count': 51660,
#    'created_at': 'Wed Feb 29 23:51:45 +0000 2012',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3118320576/97b90fce68a33eea46df4762646a846e_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3118320576/97b90fce68a33eea46df4762646a846e_normal.jpeg',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'quoted_status_id': 1022312783122235392,
#   'quoted_status_id_str': '1022312783122235392',
#   'quoted_status': {'created_at': 'Thu Jul 26 02:48:55 +0000 2018',
#    'id': 1022312783122235392,
#    'id_str': '1022312783122235392',
#    'text': 'Overheard: "Someone smashed Trump\'s star on the Hollywood walk of fame. Now he\'s down to six horcruxes." So, Twitte… https://t.co/AESZAVAUzf',
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 237845487,
#     'id_str': '237845487',
#     'name': 'George Takei',
#     'screen_name': 'GeorgeTakei',
#     'location': 'Broadway - New York, NY',
#     'url': 'https://stcky.io/ohmyyy/download',
#     'description': 'Some know me as Mr. Sulu from Star Trek but I hope all know me as a believer in, and a fighter for, the equality and dignity of all human beings.',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 2824590,
#     'friends_count': 682,
#     'listed_count': 22932,
#     'favourites_count': 2204,
#     'statuses_count': 33998,
#     'created_at': 'Thu Jan 13 19:33:56 +0000 2011',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/885170691846414339/-08XzXKy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885170691846414339/-08XzXKy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/237845487/1524917248',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'Overheard: "Someone smashed Trump\'s star on the Hollywood walk of fame. Now he\'s down to six horcruxes." So, Twitterdom. What are the other six? Write and vote up your favorites in the replies. Ready? Go.',
#     'display_text_range': [0, 204],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 4,
#    'reply_count': 92,
#    'retweet_count': 60,
#    'favorite_count': 249,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/AESZAVAUzf',
#       'expanded_url': 'https://twitter.com/i/web/status/1022312783122235392',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/3vtiTs84A3',
#    'expanded': 'https://twitter.com/georgetakei/status/1022312783122235392',
#    'display': 'twitter.com/georgetakei/st…'},
#   'is_quote_status': True,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/3vtiTs84A3',
#      'expanded_url': 'https://twitter.com/georgetakei/status/1022312783122235392',
#      'display_url': 'twitter.com/georgetakei/st…',
#      'indices': [19, 42]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532573505908'},
#  {'_id': ObjectId('5b59240b35c77d0014b73349'),
#   'created_at': 'Sat Jul 21 20:58:43 +0000 2018',
#   'id': 1020775097898917888,
#   'id_str': '1020775097898917888',
#   'text': 'Can’t wait to go home and play video games already smh',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3096943027,
#    'id_str': '3096943027',
#    'name': 'mattygeee',
#    'screen_name': 'Mattygeee1',
#    'location': 'Los Angeles, CA',
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 286,
#    'friends_count': 399,
#    'listed_count': 4,
#    'favourites_count': 7501,
#    'statuses_count': 17775,
#    'created_at': 'Thu Mar 19 01:14:05 +0000 2015',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/976278641431650304/QDCKALf8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976278641431650304/QDCKALf8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3096943027/1522005281',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '59612bd882018c51',
#    'url': 'https://api.twitter.com/1.1/geo/id/59612bd882018c51.json',
#    'place_type': 'city',
#    'name': 'Santa Monica',
#    'full_name': 'Santa Monica, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.517358, 33.995177],
#       [-118.517358, 34.050199],
#       [-118.443482, 34.050199],
#       [-118.443482, 33.995177]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532206723080'},
#  {'_id': ObjectId('5b5929588c4e2000fc01fa55'),
#   'created_at': 'Thu Jul 26 01:52:12 +0000 2018',
#   'id': 1022298509372878848,
#   'id_str': '1022298509372878848',
#   'text': 'Shi I’m 2% 10% Left chi bal',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1021923011971047425,
#   'in_reply_to_status_id_str': '1021923011971047425',
#   'in_reply_to_user_id': 899464334597816320,
#   'in_reply_to_user_id_str': '899464334597816320',
#   'in_reply_to_screen_name': 'PMGCrius007',
#   'user': {'id': 899464334597816320,
#    'id_str': '899464334597816320',
#    'name': 'Phillip Mark Graham',
#    'screen_name': 'PMGCrius007',
#    'location': 'San Diego, CA',
#    'url': 'https://www.facebook.com/PMGCrius007',
#    'description': 'PMGCrius007-Xbox One PS4-HybridPMG007 Relax Rest Calm Club-Community-Rabbi Chi Trip 👽 Emerald Moon Pearl Ruby Mercury',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 3049,
#    'friends_count': 3698,
#    'listed_count': 0,
#    'favourites_count': 6267,
#    'statuses_count': 6726,
#    'created_at': 'Mon Aug 21 02:53:03 +0000 2017',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1003915494003314689/0_c8XTqU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1003915494003314689/0_c8XTqU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/899464334597816320/1528251217',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
# ...
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532538844368'},
#  {'_id': ObjectId('5b59241135c77d0014b733b0'),
#   'created_at': 'Wed Jul 25 14:41:00 +0000 2018',
#   'id': 1022129593690480640,
#   'id_str': '1022129593690480640',
#   'text': '@ULTorreh Why thank you!!',
#   'display_text_range': [10, 25],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1022026031060922369,
#   'in_reply_to_status_id_str': '1022026031060922369',
#   'in_reply_to_user_id': 2641479654,
#   'in_reply_to_user_id_str': '2641479654',
#   'in_reply_to_screen_name': 'ULTorreh',
#   'user': {'id': 18221144,
#    'id_str': '18221144',
#    'name': 'Gloria Miele, Ph.D.',
#    'screen_name': 'GloriaMiele',
#    'location': 'Southern California',
#    'url': 'http://www.StrongerLeader.com/events/find-your-voice-leadership-retreat/',
#    'description': 'Trainer, #coach, leader, self-care enthusiast. Fighting the #opioid epidemic in CA. Marcher since 1/17. Equality, justice, and intersectionality for all!',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2776,
#    'friends_count': 3364,
#    'listed_count': 254,
#    'favourites_count': 17755,
#    'statuses_count': 32372,
#    'created_at': 'Thu Dec 18 18:29:26 +0000 2008',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'EBEBEB',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '990000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/954578924989644801/i_c6VkZ6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/954578924989644801/i_c6VkZ6_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18221144/1433195339',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'ULTorreh',
#      'name': 'T Tweets',
#      'id': 2641479654,
#      'id_str': '2641479654',
#      'indices': [0, 9]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532529660042'},
#  {'_id': ObjectId('5b592c0435c77d003438aa86'),
#   'created_at': 'Thu Jul 26 02:02:21 +0000 2018',
#   'id': 1022301062269624320,
#   'id_str': '1022301062269624320',
#   'text': '@atessier96 @LeafsNavy @XXL He had dreads not braids 🙄',
#   'display_text_range': [28, 54],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1022233129942052865,
#   'in_reply_to_status_id_str': '1022233129942052865',
#   'in_reply_to_user_id': 468714324,
#   'in_reply_to_user_id_str': '468714324',
#   'in_reply_to_screen_name': 'atessier96',
#   'user': {'id': 224042180,
#    'id_str': '224042180',
#    'name': 'GUi†∆R$ x 8Ø8$',
#    'screen_name': 'BrianSpencer302',
#    'location': 'Los Angeles, CA',
#    'url': 'https://soundcloud.com/brianspencer302/lil-aaron-quit-ft-travis-barkerbrian-spencer-remix',
#    'description': 'Guitarist🎸Producer 🎹Engineer🎛 prod. for/ worked w.👉🏾 ColdHart, Rawska, PrettyHeartBreak, Lil Gnar, Zillakami, Ghetty, The Marine Rapper, Conway, + more!',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1658,
#    'friends_count': 861,
#    'listed_count': 20,
#    'favourites_count': 1062,
#    'statuses_count': 13596,
#    'created_at': 'Wed Dec 08 00:44:02 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '131114',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021117371937800192/WkaAHpJk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021117371937800192/WkaAHpJk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/224042180/1524681292',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'atessier96',
#      'name': 'austin',
#      'id': 468714324,
#      'id_str': '468714324',
#      'indices': [0, 11]},
#     {'screen_name': 'LeafsNavy',
#      'name': 'Navy🐺',
#      'id': 817153592079613953,
#      'id_str': '817153592079613953',
#      'indices': [12, 22]},
#     {'screen_name': 'XXL',
#      'name': 'XXL Magazine',
#      'id': 14629315,
#      'id_str': '14629315',
#      'indices': [23, 27]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532570541337'},
#  {'_id': ObjectId('5b56a95b1a6d22025b8bfe2f'),
#   'created_at': 'Tue Jul 24 03:00:34 +0000 2018',
#   'id': 1021590939356127232,
#   'id_str': '1021590939356127232',
#   'text': 'I don’t listen to anyone with less money than my networth...',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 18271176,
#    'id_str': '18271176',
#    'name': 'Ghostmonious',
#    'screen_name': 'GoDjGhost',
#    'location': 'On my grind!',
#    'url': 'http://www.instagram.com/dj.spaceghost',
#    'description': 'Mr. Damn Right Dj Ghost Indmix • Ghost Da Hustla • Entertainment Mogul • A&R & Tastemaker @ http://freelabel.net | http://sg88.weebly.com | #Geekgang #Amen',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2634,
#    'friends_count': 273,
#    'listed_count': 43,
#    'favourites_count': 679,
#    'statuses_count': 49257,
#    'created_at': 'Sat Dec 20 19:32:02 +0000 2008',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/736759623332417537/fFKyHmhr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/736759623332417537/fFKyHmhr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18271176/1478236681',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532401234841'},
#  {'_id': ObjectId('5b58aae03aed5a010fe90c20'),
#   'created_at': 'Wed Jul 25 16:48:13 +0000 2018',
#   'id': 1022161611279097857,
#   'id_str': '1022161611279097857',
#   'text': '@RichardvReeves @GBurtless @rc_markets So, to get California out of its uncomfortable distinction of having the hig… https://t.co/Xa5mpDeUeX',
#   'display_text_range': [39, 140],
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': True,
#   'in_reply_to_status_id': 1022132720963600385,
#   'in_reply_to_status_id_str': '1022132720963600385',
#   'in_reply_to_user_id': 23200125,
#   'in_reply_to_user_id_str': '23200125',
#   'in_reply_to_screen_name': 'RichardvReeves',
#   'user': {'id': 1494648920,
#    'id_str': '1494648920',
#    'name': 'I Aver🌲',
#    'screen_name': 'i_aver',
#    'location': 'Los Gatos, CA',
#    'url': None,
#    'description': "#MAGA. Loathe PC. Nationalist. USAF Veteran. Repeal the 1965 Immig Act! If I unfollow, that's Twitter, not me. #UnFollowcaust",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2053,
#    'friends_count': 4502,
#    'listed_count': 92,
#    'favourites_count': 17424,
#    'statuses_count': 26845,
#    'created_at': 'Sun Jun 09 04:38:34 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/806378247856553984/WinWp1sV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806378247856553984/WinWp1sV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1494648920/1481090571',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': "@RichardvReeves @GBurtless @rc_markets So, to get California out of its uncomfortable distinction of having the highest @uscensusbureau SPM Poverty, is the Consumption-Based Measure the ticket? \nOh, why *does* CA have highest SPM Poverty, there's no Republicans.\nIt's mystery no one can solve!\n https://t.co/RLaCwSWde4",
#    'display_text_range': [39, 318],
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/RLaCwSWde4',
#       'expanded_url': 'https://www.census.gov/library/publications/2017/demo/p60-261.html',
#       'display_url': 'census.gov/library/public…',
#       'indices': [295, 318]}],
#     'user_mentions': [{'screen_name': 'RichardvReeves',
#       'name': 'Richard V. Reeves',
#       'id': 23200125,
#       'id_str': '23200125',
#       'indices': [0, 15]},
#      {'screen_name': 'GBurtless',
#       'name': 'Gary Burtless',
#       'id': 1119667508,
#       'id_str': '1119667508',
#       'indices': [16, 26]},
#      {'screen_name': 'rc_markets',
#       'name': 'RealClearMarkets',
#       'id': 389001032,
#       'id_str': '389001032',
#       'indices': [27, 38]},
#      {'screen_name': 'uscensusbureau',
#       'name': 'U.S. Census Bureau',
#       'id': 23092890,
#       'id_str': '23092890',
#       'indices': [120, 135]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/Xa5mpDeUeX',
#      'expanded_url': 'https://twitter.com/i/web/status/1022161611279097857',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}],
#    'user_mentions': [{'screen_name': 'RichardvReeves',
#      'name': 'Richard V. Reeves',
#      'id': 23200125,
#      'id_str': '23200125',
#      'indices': [0, 15]},
#     {'screen_name': 'GBurtless',
#      'name': 'Gary Burtless',
#      'id': 1119667508,
#      'id_str': '1119667508',
#      'indices': [16, 26]},
#     {'screen_name': 'rc_markets',
#      'name': 'RealClearMarkets',
#      'id': 389001032,
#      'id_str': '389001032',
#      'indices': [27, 38]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532537293630'}]

# %% [markdown]
# | | | | | |
# |-|-|-|-|-|
# | `_id`        | `truncated`                 |`user`            |`extended_tweet` | `favorited`                   |
# | `created_at` | `in_reply_to_status_id`     |`geo`             |`quote_count`    | `retweeted`                   |
# | `id`         | `in_reply_to_status_id_str` |`coordinates`     |`reply_count`    | `filter_level`                |
# | `id_str`     | `in_reply_to_user_id`       |`place`           |`retweet_count`  | `lang`                        |
# | `text`       | `in_reply_to_user_id_str`   |`contributors`    |`favorite_count` | `timestamp_ms`                |
# | `source`     | `in_reply_to_screen_name`   |`is_quote_status` |`entities`       |                               |

# %% [markdown]
# ![](https://www.evernote.com/l/AAEO7gpKcKdI5YJeGrni4GhdlBiBWdTa3YgB/image.png)

# %% [markdown]
# ![](https://i.imgflip.com/245tp9.jpg)

# %% [markdown]
# ## The Aggregation Pipeline
#
# A call to the aggregation framework defines a pipeline (figure 6.1), the **aggregation pipeline**, where the output from each step in the pipeline provides input to the next step. Each step executes a single operation on the input documents to transform the input and generate output documents.

# %% [markdown]
# ![](https://www.evernote.com/l/AAGxerRxKLZNFrjqxlYK2HPz1R11tr95FFkB/image.png)

# %% [markdown]
# ### Useful Aggregation Pipeline Operations

# %% [markdown]
# - `$project` // Specify fields to be placed in the output document.
# - `$match` // Select documents to be processed, similar to find().
# - `$limit` // Limit the number of documents to be passed to the next step.
# - `$skip` // Skip a specified number of documents.
# - `$unwind` // Expand an array, generating one output document for each array entry.
# - `$group` // Group documents by a specified key.
# - `$sort` // Sort documents.
# - `$geoNear` // Select documents near a geospatial location.
# - `$out` // Write the results of the pipeline to a collection (new in v2.6).
# - `$redact` // Control access to certain data (new in v2.6).

# %%
PROJECT = "$project"
MATCH   = "$match"
LIMIT   = "$limit"
UNWIND  = "$unwind"
GROUP   = "$group"
SORT    = "$sort"
COUNT   = "$count"

# %%
not_empty = { "$ne" : None }

# %%
cursor = collection_reference.aggregate([
    { MATCH : { "geo" : not_empty }},
    { COUNT : "geo"}
])

# %%
next(cursor)
# Out:
# {'geo': 1963}

# %%
match_non_null_geo = { MATCH : { "geo" : not_empty }}
count_geo = { COUNT : "geo"}

dag_count_non_null_geo = [
    match_non_null_geo,
    count_geo
]

# %%
next(collection_reference.aggregate(dag_count_non_null_geo))
# Out:
# {'geo': 1963}

# %% [markdown]
# ### Group Template
#
#     { $group: { _id: <expression>, <field1>: { <accumulator1> : <expression1> }, ... } }
#
# #### Accumulators
#
# - `$sum`
# - `$avg`
# - `$first`
# - `$last`
# - `$max`
# - `$min`
# - `$stdDevPop`
# - `$stdDevSamp`

# %%
greater_than_10 = { "$gt" : 10 }
sum_1 = { "$sum" : 1 }

def group_and_count(key):
    return { GROUP : {
                 "_id"   : key,
                 "count" : sum_1
                }
           }

match_count_gt_10 = { MATCH : { "count" : greater_than_10 } }

sort_by_count_descending = { SORT : { "count" : -1 } }

def limit(val):
    return { LIMIT : val }

# %%
group_and_count("$text")
# Out:
# {'$group': {'_id': '$text', 'count': {'$sum': 1}}}

# %%
list(collection_reference.aggregate(
    [
        group_and_count('$lang'),
        match_count_gt_10, 
        sort_by_count_descending,
        limit(5)
    ]
))
# Out:
# [{'_id': 'en', 'count': 13875},
#  {'_id': 'und', 'count': 1394},
#  {'_id': 'es', 'count': 358},
#  {'_id': 'ar', 'count': 115},
#  {'_id': 'fr', 'count': 100}]

# %%
not_an_empty_array             = { "$ne" : [] }
match_non_empty_hashtag_arrays = { MATCH : { "entities.hashtags" : not_an_empty_array } }
project_to_text_only           = { PROJECT : { "text" : "$entities.hashtags.text", "_id" :0 } }
unwind_text                    = { UNWIND : "$text" }

# %%
list(collection_reference.aggregate(
    [
        match_non_empty_hashtag_arrays,
        project_to_text_only,
        unwind_text,
        limit(10)
    ]
))
# Out:
# [{'text': 'Dodgers'},
#  {'text': 'DeadBirds'},
#  {'text': 'Dodgers'},
#  {'text': 'DeadBirds'},
#  {'text': 'thestruggleisreal'},
#  {'text': 'actorslife'},
#  {'text': 'poolday'},
#  {'text': 'heatwave'},
#  {'text': 'littlethings'},
#  {'text': 'LHHH'}]

# %%
list(collection_reference.aggregate(
    [
        match_non_empty_hashtag_arrays,
        project_to_text_only,
        unwind_text,
        group_and_count('$text'),
        match_count_gt_10, 
        sort_by_count_descending,
        limit(10)
    ]
))
# Out:
# [{'_id': 'job', 'count': 78},
#  {'_id': 'Hiring', 'count': 65},
#  {'_id': 'LosAngeles', 'count': 64},
#  {'_id': 'CareerArc', 'count': 58},
#  {'_id': 'earthquake', 'count': 35},
#  {'_id': 'Repost', 'count': 31},
#  {'_id': 'quake', 'count': 30},
#  {'_id': 'california', 'count': 28},
#  {'_id': 'hiring', 'count': 26},
#  {'_id': 'love', 'count': 25}]

# %%
job_hashtags      = ['job', 'jobs', 'hiring', 'careerarc']
location_hashtags = ['california', 'losangeles', 'la', 'santamonica', 'glendale', 'paloalto']
project_to_lower  = { PROJECT : { "text" : {"$toLower" : "$text"} } }
match_not_in_bad  = { MATCH : { "_id" : { "$nin" : job_hashtags + location_hashtags}}}

# %%
list(collection_reference.aggregate(
    [
        match_non_empty_hashtag_arrays,
        project_to_text_only,
        unwind_text,
        project_to_lower,
        group_and_count('$text'),
        match_not_in_bad,
        match_count_gt_10, 
        sort_by_count_descending,
        limit(50)
    ]
))
# Out:
# [{'_id': 'earthquake', 'count': 35},
#  {'_id': 'savecolony', 'count': 33},
#  {'_id': 'love', 'count': 31},
#  {'_id': 'repost', 'count': 31},
#  {'_id': 'quake', 'count': 30},
#  {'_id': 'dodgers', 'count': 24},
#  {'_id': 'queensugar', 'count': 20},
#  {'_id': 'wcw', 'count': 19},
#  {'_id': 'hollywood', 'count': 15},
#  {'_id': 'iexplorechat', 'count': 15},
#  {'_id': 'christopherglenn', 'count': 14},
#  {'_id': 's2pundercover', 'count': 13},
#  {'_id': 'convincesomeonetovotein4words', 'count': 13},
#  {'_id': 'maga', 'count': 13},
#  {'_id': 'photography', 'count': 13},
#  {'_id': 'mixshow', 'count': 12},
#  {'_id': 'grindmode', 'count': 12},
#  {'_id': 'edm', 'count': 12},
#  {'_id': 'trump', 'count': 11},
#  {'_id': 'wednesdaywisdom', 'count': 11},
#  {'_id': 'outliers', 'count': 11}]
